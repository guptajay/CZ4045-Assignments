# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Data/review.csv')

# %%
df.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  8aoJJdKEO3ypoZNszpPu7Q  bGgAL09pxLnV_FFgR4ZADg  ZBE-H_aUlicix_9vUGQPIQ
# 1  J5NOCLdhuhor7USRhtYZ8w  pFCb-1j6oI3TDjr26h2cJQ  e-YnECeZNt8ngm0tu4X9mQ
# 2  PXiLWAYRt3xnHaJ8MB4rzw  mEzc6LeTNiQgIVsq3poMbg  j7HO1YeMQGYo3KibMXZ5vg
# 3  VrLarvxZYJm74yAqtpe9PQ  o-zUN2WEZgjQS7jnNsec0g  7e3PZzUpG5FYOTGt3O3ePA
# 4  C1CUpidlVFprUCkApqzCmA  Wlx0iBXJvk4x0EeOt2Bz1Q  vuHzLZ7nAeT-EiecOkS5Og
#
#    stars  useful  funny  cool  \
# 0    5.0       0      0     0
# 1    4.0       0      0     0
# 2    5.0       2      1     3
# 3    3.0       0      0     0
# 4    1.0      11      0     3
#
#                                                 text                 date
# 0  We had my Mother's Birthday Party here on 10/2...  2016-11-09 20:07:25
# 1  Good Korean grill near Eaton Centre. The marin...  2015-12-05 05:06:43
# 2  Was recommended to try this place by few peopl...  2014-10-11 05:16:15
# ...

# %%
print('Number of rows : ', len(df))
# Out:
# Number of rows :  15300

# %% [markdown]
# ## All the buisness id have the same number of reviews

# %%
print('Number of buisnesses : ', len(set(df['business_id'])))
# Out:
# Number of buisnesses :  153

# %%
df['business_id'].value_counts()
# Out:
# ZBE-H_aUlicix_9vUGQPIQ    100
# 4no7JcP4CYasqxdxmrTGRA    100
# a6mYyhGgxWhnhrGDHzOTPA    100
# ZP7U4qUCMjIvasWV7a_mgg    100
# QxRKQ_Lzu4lMOejwVgcdAg    100
#                          ...
# aDHD7nASfqiQBB6YXy2aGA    100
# ih_bb1SaYvsMYfdykhYh2g    100
# NnxwkiBvSSyKeFiez0DDcQ    100
# c0t81YxNqZQuTJrTfn3QYA    100
# cPzIic1AqH1ApTVVaww5hw    100
# Name: business_id, Length: 153, dtype: int64

# %%
df['stars'].value_counts().plot(kind='bar', figsize=(12,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Analysis on User

# %%
print('Number of distinct users : ', len(set(df['user_id'])))
# Out:
# Number of distinct users :  13926

# %%
users = df[['user_id', 'business_id']].groupby(['user_id']).count().sort_values(by = 'business_id', ascending=False)

# %%
users[users['business_id'] > 3].plot(kind='bar', figsize=(24,12))
# Out:
# <AxesSubplot:xlabel='user_id'>

# %%
df[df['user_id'] == '--Qh8yKWAvIP4V4K8ZPfHA']
# Out:
#                     review_id                 user_id             business_id  \
# 2641   iwk9qKEYJFkiF2JWkjsgBA  --Qh8yKWAvIP4V4K8ZPfHA  paCgjLEUEVM38VZ6Sjghgg
# 15025  SHVd6mnBcTaYwnh1-sI3Vw  --Qh8yKWAvIP4V4K8ZPfHA  cPzIic1AqH1ApTVVaww5hw
#
#        stars  useful  funny  cool  \
# 2641     4.0       2      1     0
# 15025    3.0       0      0     0
#
#                                                     text                 date
# 2641   I've been here twice before to watch live impr...  2014-03-23 15:40:55
# 15025  This is my 2nd time eating here. This time aro...  2012-09-09 14:55:28
